# %%
# !pip install selenium

# %%
import pandas as pd
import numpy as np
import requests
from selenium import webdriver

# %%
# url = 'https://www.youtube.com/c/JohnWatsonRooney/videos'
url = 'https://www.youtube.com/channel/UC8tgRQ7DOzAbn9L7zDL8mLg/video?view=0&sort=p'

driver = webdriver.Chrome('C:\Program Files\Google\Chrome\Application\chromedriver.exe')
driver.get(url)

videos = driver.find_elements_by_class_name('style-scope ytd-grid-video-renderer')
video_list = []

for video in videos:
    title = driver.find_element_by_xpath('.//*[@id="video-title"]').text.strip()
    views = driver.find_element_by_xpath('.//*[@id="metadata-line"]/span[1]').text.strip() 
    when = driver.find_element_by_xpath('.//*[@id="metadata-line"]/span[2]').text.strip()
    #print(title,views,when)
    vid_item = {
        'title':title,
        'views':views,
        'posted':when
    }
    
    video_list.append(vid_item)
# Out:
# <ipython-input-18-a576883460c9>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\Program Files\Google\Chrome\Application\chromedriver.exe')
# <ipython-input-18-a576883460c9>:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   videos = driver.find_elements_by_class_name('style-scope ytd-grid-video-renderer')
# <ipython-input-18-a576883460c9>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title = driver.find_element_by_xpath('.//*[@id="video-title"]').text.strip()
# <ipython-input-18-a576883460c9>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   views = driver.find_element_by_xpath('.//*[@id="metadata-line"]/span[1]').text.strip()
# ...

# %%
video_channel = pd.DataFrame(video_list)
video_channel
# Out:
#                                                 title       views     posted
# 0   HTTPX is a great ASYNC alternative to Requests...  2.1K views  1 day ago
# 1   HTTPX is a great ASYNC alternative to Requests...  2.1K views  1 day ago
# 2   HTTPX is a great ASYNC alternative to Requests...  2.1K views  1 day ago
# 3   HTTPX is a great ASYNC alternative to Requests...  2.1K views  1 day ago
# 4   HTTPX is a great ASYNC alternative to Requests...  2.1K views  1 day ago
# 5   HTTPX is a great ASYNC alternative to Requests...  2.1K views  1 day ago
# 6   HTTPX is a great ASYNC alternative to Requests...  2.1K views  1 day ago
# 7   HTTPX is a great ASYNC alternative to Requests...  2.1K views  1 day ago
# 8   HTTPX is a great ASYNC alternative to Requests...  2.1K views  1 day ago
# 9   HTTPX is a great ASYNC alternative to Requests...  2.1K views  1 day ago
# 10  HTTPX is a great ASYNC alternative to Requests...  2.1K views  1 day ago
# ...
